# %%
g = lambda x: x**2

# %%
g(4)
# Out:
# 16

# %%
def i(f) : return lambda x: x*f + x

# %%
s = i(2) #passing f value first
s(8) #passing x value to complete calculation of equation
# Out:
# 24

# %%
import pandas as pd
df = pd.read_csv(r"\\USHOUHOME02\vakkam\Desktop\Sample Perf.csv",delimiter=',')
df['REINVESTMENT_FACTOR'] = ((df[:-1].REPORT_CONTRIB_SUM_CI_RATE[::-1]+1).cumprod())
print(df)
# Out:
#    PERFORM_DATE  REPORT_CONTRIB_SUM_CI_RATE  REINVESTMENT_FACTOR
# 0      1/1/2017                    0.000000             1.018167
# 1      1/2/2017                    0.000495             1.018167
# 2      1/3/2017                    0.006535             1.017663
# 3      1/4/2017                    0.006328             1.011055
# 4      1/5/2017                    0.000930             1.004698
# 5      1/6/2017                    0.002419             1.003764
# 6      1/7/2017                    0.000000             1.001342
# 7      1/8/2017                    0.000000             1.001342
# 8      1/9/2017                   -0.003557             1.001342
# 9     1/10/2017                    0.000755             1.004917
# 10    1/11/2017                    0.001517             1.004159
# 11    1/12/2017                   -0.000240             1.002638
# 12    1/13/2017                    0.001302             1.002878
# ...
